# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# Load the cleaned credit score training data
df = pd.read_csv('credit_score_cleaned_train.csv')

# Drop unnecessary columns from the DataFrame
df = df.drop(columns=['id', 'customer_id', 'name', 'monthly_inhand_salary', 'type_of_loan'])

# Create a mapping dictionary to convert month names to numbers
month_mapping = {
    'January': 1,
    'February': 2,
    'March': 3,
    'April': 4,
    'May': 5,
    'June': 6,
    'July': 7,
    'August': 8
}

# Use the mapping dictionary to convert month names in the DataFrame to numbers
df['month'] = df['month'].map(month_mapping)

# %%
df.T
# Out:
#                                                     0      \
# month                                                   1
# age                                                    23
# ssn                                           821-00-0265
# occupation                                      Scientist
# annual_income                                    19114.12
# total_emi_per_month                             49.574947
# num_bank_accounts                                       3
# num_credit_card                                         4
# interest_rate                                           3
# num_of_loan                                             4
# delay_from_due_date                                     3
# num_of_delayed_payment                                  7
# changed_credit_limit                                11.27
# num_credit_inquiries                                    4
# credit_mix                                           Good
# ...

# %%
df.describe().T
# Out:
#                              count          mean           std         min  \
# month                     100000.0      4.500000      2.291299     1.00000
# age                       100000.0     33.309240     10.764996    14.00000
# annual_income             100000.0  50505.123439  38299.422075  7005.93000
# total_emi_per_month       100000.0    107.043617    130.035096     0.00000
# num_bank_accounts         100000.0      5.368800      2.593279     0.00000
# num_credit_card           100000.0      5.533640      2.067073     0.00000
# interest_rate             100000.0     14.532080      8.741330     1.00000
# num_of_loan               100000.0      3.532880      2.446356     0.00000
# delay_from_due_date       100000.0     21.068780     14.860104    -5.00000
# num_of_delayed_payment    100000.0     13.334050      6.271409     0.00000
# changed_credit_limit      100000.0     10.389303      6.789784    -6.49000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   month                     100000 non-null  int64
#  1   age                       100000 non-null  int64
#  2   ssn                       100000 non-null  object
#  3   occupation                100000 non-null  object
#  4   annual_income             100000 non-null  float64
#  5   total_emi_per_month       100000 non-null  float64
#  6   num_bank_accounts         100000 non-null  int64
#  7   num_credit_card           100000 non-null  int64
#  8   interest_rate             100000 non-null  int64
#  9   num_of_loan               100000 non-null  int64
#  10  delay_from_due_date       100000 non-null  int64
#  11  num_of_delayed_payment    100000 non-null  int64
#  12  changed_credit_limit      100000 non-null  float64
# ...

# %%
df['credit_history_age'].value_counts().sort_index()
# Out:
# credit_history_age
# 1        2
# 2       15
# 3       22
# 4       37
# 5       45
#       ...
# 400    144
# 401     97
# 402     53
# 403     15
# 404     15
# Name: count, Length: 404, dtype: int64

# %%
result = df.groupby('ssn').apply(lambda x: x.head(20))
print(result)
# Out:
#                    month  age          ssn     occupation  annual_income  \
# ssn
# 000-08-1349 98848      1   49  000-08-1349  Media_Manager      65937.120
#             98849      2   49  000-08-1349  Media_Manager      65937.120
#             98850      3   49  000-08-1349  Media_Manager      65937.120
#             98851      4   49  000-08-1349  Media_Manager      65937.120
#             98852      5   49  000-08-1349  Media_Manager      65937.120
# ...                  ...  ...          ...            ...            ...
# 999-99-3421 53179      4   31  999-99-3421      Developer      10210.735
#             53180      5   31  999-99-3421      Developer      10210.735
#             53181      6   31  999-99-3421      Developer      10210.735
#             53182      7   31  999-99-3421      Developer      10210.735
#             53183      8   31  999-99-3421      Developer      10210.735
#
#                    total_emi_per_month  num_bank_accounts  num_credit_card  \
# ssn
# ...

# %%
RANDOM_SEED = 42

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='credit_score', data=df, palette='pastel')
plt.title('Distribution of Target Variable: Credit_Score')
plt.xlabel('Credit_Score')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\10744\AppData\Local\Temp\ipykernel_30900\695653184.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='credit_score', data=df, palette='pastel')

# %%
# Remove duplicate SSNs
unique_ssn = df['ssn'].drop_duplicates()

# Extract the first three digits of the SSNs
unique_ssn = unique_ssn.str.split('-', expand=True)[0].astype('int64').reset_index(drop=True)

# Define a function to determine the region based on the area number
def get_region(area_number):
    area_number = int(area_number)
    if 1 <= area_number <= 3:
        return 'New Hampshire'
    elif 4 <= area_number <= 7:
        return 'Maine'
    elif 8 <= area_number <= 9:
        return 'Vermont'
    elif 10 <= area_number <= 34:
        return 'Massachusetts'
    elif 35 <= area_number <= 39:
        return 'Rhode Island'
    elif 40 <= area_number <= 49:
        return 'Connecticut'
    elif 50 <= area_number <= 134:
        return 'New York'
    elif 135 <= area_number <= 158:
        return 'New Jersey'
    elif 159 <= area_number <= 211:
        return 'Pennsylvania'
    elif 212 <= area_number <= 220:
        return 'Maryland'
    elif 221 <= area_number <= 222:
        return 'Delaware'
    elif 223 <= area_number <= 231:
        return 'Virginia'
    elif 691 <= area_number <= 699:
        return 'Virginia'
    elif 232 <= area_number <= 236:
        return 'West Virginia'
    elif area_number == 232:
        return 'North Carolina'
    elif 237 <= area_number <= 246:
        return 'North Carolina'
    elif 681 <= area_number <= 690:
        return 'North Carolina'
    elif 247 <= area_number <= 251:
        return 'South Carolina'
    elif 654 <= area_number <= 658:
        return 'South Carolina'
    elif 252 <= area_number <= 260:
        return 'Georgia'
    elif 667 <= area_number <= 675:
        return 'Georgia'
    elif 261 <= area_number <= 267:
        return 'Florida'
    elif 589 <= area_number <= 595:
        return 'Florida'
    elif 766 <= area_number <= 772:
        return 'Florida'
    elif 268 <= area_number <= 302:
        return 'Ohio'
    elif 303 <= area_number <= 317:
        return 'Indiana'
    elif 318 <= area_number <= 361:
        return 'Illinois'
    elif 362 <= area_number <= 386:
        return 'Michigan'
    elif 387 <= area_number <= 399:
        return 'Wisconsin'
    elif 400 <= area_number <= 407:
        return 'Kentucky'
    elif 408 <= area_number <= 415:
        return 'Tennessee'
    elif 756 <= area_number <= 763:
        return 'Tennessee'
    elif 416 <= area_number <= 424:
        return 'Alabama'
    elif 425 <= area_number <= 428:
        return 'Mississippi'
    elif 587 <= area_number <= 588:
        return 'Mississippi'
    elif 752 <= area_number <= 755:
        return 'Mississippi'
    elif 429 <= area_number <= 432:
        return 'Arkansas'
    elif 676 <= area_number <= 679:
        return 'Arkansas'
    elif 433 <= area_number <= 439:
        return 'Louisiana'
    elif 659 <= area_number <= 665:
        return 'Louisiana'
    elif 440 <= area_number <= 448:
        return 'Oklahoma'
    elif 449 <= area_number <= 467:
        return 'Texas'
    elif 627 <= area_number <= 645:
        return 'Texas'
    elif 468 <= area_number <= 477:
        return 'Minnesota'
    elif 478 <= area_number <= 485:
        return 'Iowa'
    elif 486 <= area_number <= 500:
        return 'Missouri'
    elif 501 <= area_number <= 502:
        return 'North Dakota'
    elif 503 <= area_number <= 504:
        return 'South Dakota'
    elif 505 <= area_number <= 508:
        return 'Nebraska'
    elif 509 <= area_number <= 515:
        return 'Kansas'
    elif 516 <= area_number <= 517:
        return 'Montana'
    elif 518 <= area_number <= 519:
        return 'Idaho'
    elif area_number == 520:
        return 'Wyoming'
    elif 521 <= area_number <= 524:
        return 'Colorado'
    elif 650 <= area_number <= 653:
        return 'Colorado'
    elif 525 <= area_number <= 585:
        return 'New Mexico'
    elif 648 <= area_number <= 649:
        return 'New Mexico'
    elif 526 <= area_number <= 527:
        return 'Arizona'
    elif 600 <= area_number <= 601:
        return 'Arizona'
    elif 764 <= area_number <= 765:
        return 'Arizona'
    elif 528 <= area_number <= 529:
        return 'Utah'
    elif 646 <= area_number <= 647:
        return 'Utah'
    elif area_number == 530:
        return 'Nevada'
    elif area_number == 680:
        return 'Nevada'
    elif 531 <= area_number <= 539:
        return 'Washington'
    elif 540 <= area_number <= 544:
        return 'Oregon'
    elif 545 <= area_number <= 573:
        return 'California'
    elif 602 <= area_number <= 626:
        return 'California'
    elif area_number == 574:
        return 'Alaska'
    elif 575 <= area_number <= 576:
        return 'Hawaii'
    elif 750 <= area_number <= 751:
        return 'Hawaii'
    elif 577 <= area_number <= 579:
        return 'District of Columbia'
    elif area_number == 580:
        return 'Virgin Islands'
    elif 580 <= area_number <= 584:
        return 'Puerto Rico'
    elif 596 <= area_number <= 599:
        return 'Puerto Rico'  # Example region, can be replaced
    elif area_number == 586:
        return 'Guam'
    elif 700 <= area_number <= 728:
        return 'Railroad Board'
    elif 729 <= area_number <= 733:
        return 'Enumeration at Entry'
    else:
        return 'Unknown'

# Create a results DataFrame
result_df = pd.DataFrame({'area_number': unique_ssn})

# Apply the get_region function to determine the region for each area number
result_df['region'] = result_df['area_number'].apply(get_region)

# Display the results
print(result_df)
# Out:
#        area_number         region
# 0              821        Unknown
# 1                4          Maine
# 2              486       Missouri
# 3               72       New York
# 4              615     California
# ...            ...            ...
# 12495          340       Illinois
# 12496          868        Unknown
# 12497          133       New York
# 12498           31  Massachusetts
# 12499           78       New York
#
# [12500 rows x 2 columns]

# %%
#https://www.uclaisap.org/trackingmanual/manual/appendix-G.html

# %%
region_counts = result_df['region'].value_counts()

print(region_counts)
# Out:
# region
# Unknown                 3162
# New York                1048
# New Mexico               805
# Pennsylvania             679
# Illinois                 575
# Ohio                     454
# Texas                    444
# Railroad Board           332
# Massachusetts            323
# New Jersey               313
# California               306
# Michigan                 284
# Florida                  259
# Virginia                 247
# North Carolina           242
# Georgia                  211
# Tennessee                184
# Missouri                 170
# Indiana                  164
# Louisiana                160
# Wisconsin                147
# Alabama                  138
# Minnesota                135
# Connecticut              131
# Oklahoma                 128
# Mississippi              126
# Maryland                 124
# Arkansas                 104
# South Carolina            99
# Kentucky                  94
# Kansas                    93
# ...

# %%
# Group the DataFrame by SSN
grouped = df.groupby('ssn')

result = []

for ssn, group in grouped:
    # Get feature columns for different months
    unique_data = group.drop(columns=['ssn', 'month'])  # Remove the ssn and month columns

    same = {}
    different = {}

    for col in unique_data.columns:
        values = unique_data[col].unique()  # Get unique values for the column
        if len(values) == 1:
            same[col] = values[0]  # If there's only one unique value, record it in same
        else:
            different[col] = values.tolist()  # Otherwise, record all different values

    result.append({'ssn': ssn, 'same': same, 'different': different})

# Convert the result to a DataFrame
result_df = pd.DataFrame(result)

# %%
print(result_df['different'])
# Out:
# 0        {'delay_from_due_date': [24, 22], 'num_of_dela...
# 1        {'age': [43, 44], 'num_of_delayed_payment': [1...
# 2        {'age': [18, 19], 'delay_from_due_date': [11, ...
# 3        {'delay_from_due_date': [11, 13, 7], 'num_of_d...
# 4        {'delay_from_due_date': [21, 23, 19], 'num_of_...
#                                ...
# 12495    {'delay_from_due_date': [28, 26, 24, 29], 'num...
# 12496    {'delay_from_due_date': [46, 49, 41], 'num_of_...
# 12497    {'delay_from_due_date': [24, 26, 27, 30, 28], ...
# 12498    {'delay_from_due_date': [13, 18], 'num_of_dela...
# 12499    {'age': [30, 31], 'delay_from_due_date': [17, ...
# Name: different, Length: 12500, dtype: object

# %%
# Find the union of all different features
feature_set = set()

# Iterate through each row in the result DataFrame
for index, row in result_df.iterrows():
    different_dict = row['different']
    feature_set.update(different_dict.keys())  # Add feature names to the set

# Convert the set to a list (optional)
feature_list = list(feature_set)

# Print the union of feature names
print(feature_list)
# Out:
# ['num_of_delayed_payment', 'credit_history_age', 'age', 'total_emi_per_month', 'num_credit_card', 'changed_credit_limit', 'num_bank_accounts', 'credit_score', 'amount_invested_monthly', 'payment_behaviour', 'num_credit_inquiries', 'monthly_balance', 'delay_from_due_date', 'credit_utilization_ratio']

# %% [markdown]
# ## Neural Network Multi-Class classification

# %%
#https://towardsdatascience.com/pytorch-tabular-multiclass-classification-9f8211a123ab

# %%
import numpy as np, pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import subplots
from sklearn.linear_model import \
     (LinearRegression,
      LogisticRegression,
      Lasso)
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.model_selection import \
     (train_test_split,
      GridSearchCV)
import torch
from torch import nn
import torch.optim as optim
from torch.optim import RMSprop
from torch.utils.data import DataLoader, TensorDataset, WeightedRandomSampler

# %%
RANDOM_SEED = 42
data = pd.read_csv('processed_credit_score_data.csv')
data.T
# Out:
#                               0          1          2          3      \
# month                             1          2          3          4
# age                              23         23         23         23
# annual_income              19114.12   19114.12   19114.12   19114.12
# total_emi_per_month       49.574947  49.574947  49.574947  49.574947
# num_bank_accounts                 3          3          3          3
# num_credit_card                   4          4          4          4
# interest_rate                     3          3          3          3
# num_of_loan                       4          4          4          4
# delay_from_due_date               3         -1          3          5
# num_of_delayed_payment            7          7          7          4
# changed_credit_limit          11.27      11.27      11.27       6.27
# num_credit_inquiries              4          4          4          4
# credit_mix                     Good       Good       Good       Good
# ...

# %%
data['credit_mix'] = data['credit_mix'].map({'Good': 2, 'Standard': 1, 'Bad': 0})

data['credit_mix'] = pd.to_numeric(data['credit_mix'], downcast='integer')

# %%
data.columns
# Out:
# Index(['month', 'age', 'annual_income', 'total_emi_per_month',
#        'num_bank_accounts', 'num_credit_card', 'interest_rate', 'num_of_loan',
#        'delay_from_due_date', 'num_of_delayed_payment', 'changed_credit_limit',
#        'num_credit_inquiries', 'credit_mix', 'outstanding_debt',
#        'credit_utilization_ratio', 'credit_history_age',
#        'payment_of_min_amount', 'amount_invested_monthly', 'monthly_balance',
#        'credit_score', 'spent', 'payment', 'Accountant', 'Architect',
#        'Developer', 'Doctor', 'Engineer', 'Entrepreneur', 'Journalist',
#        'Lawyer', 'Manager', 'Mechanic', 'Media_Manager', 'Musician',
#        'Scientist', 'Teacher', 'Writer'],
#       dtype='object')

# %%
data = data.drop(columns=['month'])
#data = pd.get_dummies(data, drop_first=True)
print(data.columns)
print(data.shape)
# Out:
# Index(['age', 'annual_income', 'total_emi_per_month', 'num_bank_accounts',
#        'num_credit_card', 'interest_rate', 'num_of_loan',
#        'delay_from_due_date', 'num_of_delayed_payment', 'changed_credit_limit',
#        'num_credit_inquiries', 'credit_mix', 'outstanding_debt',
#        'credit_utilization_ratio', 'credit_history_age',
#        'payment_of_min_amount', 'amount_invested_monthly', 'monthly_balance',
#        'credit_score', 'spent', 'payment', 'Accountant', 'Architect',
#        'Developer', 'Doctor', 'Engineer', 'Entrepreneur', 'Journalist',
#        'Lawyer', 'Manager', 'Mechanic', 'Media_Manager', 'Musician',
#        'Scientist', 'Teacher', 'Writer'],
#       dtype='object')
# (100000, 36)

# %%
# Define the feature variables X and the target variable Y
Y = data['credit_score']  # Target variable
X = data.drop(columns=['credit_score'])  # Feature variables (drop the target variable)

# %%
# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, 
                                                    stratify=Y, random_state=RANDOM_SEED)

# Define the columns that need to be scaled with RobustScaler
robust_columns = ['total_emi_per_month', 'amount_invested_monthly', 'monthly_balance']

# Define the columns that need to be scaled with StandardScaler (all non-robust columns)
standard_columns = [col for col in X_train.columns if col not in robust_columns]

# Create a ColumnTransformer to apply different scalers to specified columns
scaler = ColumnTransformer(
    transformers=[
        ('standard', StandardScaler(), standard_columns),
        ('robust', RobustScaler(), robust_columns)
    ]
)

# Fit the scaler to the training data and transform it
X_train_scaled = scaler.fit_transform(X_train)

# Apply the same transformation to the test data (without fitting again)
X_test_scaled = scaler.transform(X_test)

# Convert the scaled data to PyTorch tensors
X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32)

# Convert the target variables to LongTensors
Y_train_tensor = torch.tensor(Y_train.values, dtype=torch.long)  # Convert to one-dimensional tensor
Y_test_tensor = torch.tensor(Y_test.values, dtype=torch.long)    # Convert to one-dimensional tensor

# Display the results
print("X_train_tensor:", X_train_tensor)
print("Y_train_tensor:", Y_train_tensor)
# Out:
# X_train_tensor: tensor([[ 0.0677, -0.6101,  0.2442,  ..., -0.0126,  0.0396, -0.1983],
#         [-1.3267, -0.4232, -0.9139,  ..., -0.1099, -0.4487,  0.3485],
#         [-0.2112, -1.0050, -0.1419,  ..., -0.3271, -0.2562, -0.2257],
#         ...,
#         [ 1.2762, -0.5014,  0.6302,  ..., -0.0081,  1.0016, -0.9498],
#         [-0.3042, -1.0950,  0.6302,  ..., -0.2265, -0.4118, -0.4331],
#         [-0.5830,  0.4684,  0.6302,  ...,  0.5157,  0.9372,  0.1090]])
# Y_train_tensor: tensor([1, 1, 1,  ..., 1, 0, 1])

# %%
# Create a dataset from the training tensors
train_dataset = TensorDataset(X_train_tensor, Y_train_tensor)

# Create a data loader for the training dataset with specified batch size and shuffling
train_loader = DataLoader(train_dataset, batch_size=512, shuffle=True)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class CreditModel(nn.Module):
    def __init__(self, input_features, output_features, dropout_rate=0.25):
        super(CreditModel, self).__init__()
        # Define a sequential stack of linear layers with batch normalization and dropout
        self.linear_layer_stack = nn.Sequential(
            nn.Linear(in_features=input_features, out_features=256),  # First hidden layer
            nn.BatchNorm1d(256),  # Batch normalization
            nn.ReLU(),  # Activation function
            nn.Dropout(dropout_rate),  # Dropout for regularization
            nn.Linear(in_features=256, out_features=512),  # Second hidden layer
            nn.BatchNorm1d(512),  # Batch normalization
            nn.ReLU(),  # Activation function
            nn.Dropout(dropout_rate),  # Dropout for regularization
            nn.Linear(in_features=512, out_features=256),  # Third hidden layer
            nn.BatchNorm1d(256),  # Batch normalization
            nn.ReLU(),  # Activation function
            nn.Dropout(dropout_rate),  # Dropout for regularization
            nn.Linear(in_features=256, out_features=128),  # Fourth hidden layer
            nn.BatchNorm1d(128),  # Batch normalization
            nn.ReLU(),  # Activation function
            nn.Dropout(dropout_rate),  # Dropout for regularization
            nn.Linear(in_features=128, out_features=256),  # Fifth hidden layer
            nn.BatchNorm1d(256),  # Batch normalization
            nn.ReLU(),  # Activation function
            nn.Dropout(0.2),  # Dropout for regularization
            nn.Linear(in_features=256, out_features=output_features)  # Output layer
        )

    def forward(self, x_credit):
        # Define the forward pass through the model
        x = self.linear_layer_stack(x_credit)
        return x

# Instantiate the model with specified input and output features
model = CreditModel(input_features=35, 
                    output_features=3, 
                    dropout_rate=0.25).to(device)  # Move model to the specified device

# %%
# Define the loss function
criterion = nn.CrossEntropyLoss()  # Cross-entropy loss for multi-class classification

# Define the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Adam optimizer with a learning rate of 0.001

num_epochs = 750  # Total number of training epochs
patience = 70  # Number of epochs to wait for improvement in validation accuracy
best_val_accuracy = 0  # Variable to track the best validation accuracy
epochs_without_improvement = 0  # Counter for epochs without improvement in validation accuracy

# %%
# Lists to record loss and accuracy
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

# Training loop for the specified number of epochs
for epoch in range(num_epochs):
    model.train()  # Switch to training mode
    running_loss = 0.0
    correct = 0
    total = 0
    
    # Iterate over batches in the training data
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)  # Move data to the specified device
        optimizer.zero_grad()  # Clear gradients from the previous step
        outputs = model(inputs)  # Forward pass
        loss = criterion(outputs, labels)  # Calculate loss
        loss.backward()  # Backward pass
        optimizer.step()  # Update weights
        running_loss += loss.item()  # Accumulate loss
        
        # Calculate training accuracy
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    # Calculate average training loss and accuracy
    average_loss = running_loss / len(train_loader)
    train_losses.append(average_loss)  # Record training loss
    train_accuracies.append(correct / total)  # Record training accuracy

    # Evaluation on validation set
    model.eval()  # Switch to evaluation mode
    val_running_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():  # Disable gradient calculation for validation
        val_outputs = model(X_test_tensor.to(device))  # Ensure test data is also on the GPU
        val_loss = criterion(val_outputs, Y_test_tensor.to(device))  # Calculate validation loss
        val_running_loss = val_loss.item()  # Get validation loss
        _, val_predictions = torch.max(val_outputs, dim=1)

        # Calculate validation accuracy
        val_accuracy = accuracy_score(Y_test_tensor.cpu(), val_predictions.cpu())  # Compute validation accuracy
        val_accuracies.append(val_accuracy)  # Record validation accuracy

    val_losses.append(val_running_loss)  # Record validation loss

    # Print information every ten epochs
    if (epoch + 1) % 10 == 0:
        print(f'''Epoch [{epoch + 1}/{num_epochs}], 
            Train Loss: {average_loss:.4f}, 
            Val Loss: {val_running_loss:.4f}, 
            Val Accuracy: {val_accuracy:.4f}''')
    
    # Early stopping mechanism
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        epochs_without_improvement = 0  # Reset counter if validation accuracy improves
    else:
        epochs_without_improvement += 1  # Increment counter if no improvement
        if epochs_without_improvement >= patience:  # Check for early stopping condition
            print("Early stopping triggered.")
            break

# Create a DataFrame to plot loss and accuracy curves
metrics_df = pd.DataFrame({
    'Train Loss': train_losses,
    'Val Loss': val_losses,
    'Train Accuracy': train_accuracies,
    'Val Accuracy': val_accuracies
})

# Plotting the loss and accuracy curves
plt.figure(figsize=(12, 6))

# Plot training loss and validation loss
plt.plot(metrics_df['Train Loss'], color='red', label='Train Loss')
plt.plot(metrics_df['Val Loss'], color='orange', label='Val Loss')

# Plot training accuracy and validation accuracy
plt.plot(metrics_df['Train Accuracy'], color='blue', label='Train Accuracy')
plt.plot(metrics_df['Val Accuracy'], color='cyan', label='Val Accuracy')

# Set legend, title, and labels
plt.title('Training and Validation Loss and Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss / Accuracy')
plt.legend()
plt.grid()
plt.show()  # Display the plot
# Out:
# Epoch [10/750],
#             Train Loss: 0.6518,
#             Val Loss: 0.6352,
#             Val Accuracy: 0.7211
# Epoch [20/750],
#             Train Loss: 0.6182,
#             Val Loss: 0.6076,
#             Val Accuracy: 0.7338
# Epoch [30/750],
#             Train Loss: 0.5869,
#             Val Loss: 0.5787,
#             Val Accuracy: 0.7436
# Epoch [40/750],
#             Train Loss: 0.5606,
#             Val Loss: 0.5499,
#             Val Accuracy: 0.7584
# Epoch [50/750],
#             Train Loss: 0.5348,
#             Val Loss: 0.5295,
#             Val Accuracy: 0.7706
# Epoch [60/750],
#             Train Loss: 0.5186,
#             Val Loss: 0.5075,
#             Val Accuracy: 0.7801
# Epoch [70/750],
#             Train Loss: 0.4984,
#             Val Loss: 0.4970,
#             Val Accuracy: 0.7881
# Epoch [80/750],
#             Train Loss: 0.4865,
#             Val Loss: 0.4843,
#             Val Accuracy: 0.7929
# Epoch [90/750],
# ...

# %%
# Model evaluation
model.eval()  # Switch to evaluation mode
with torch.no_grad():  # Disable gradient calculation
    correct = 0
    total = 0
    all_labels = []  # Store all true labels
    all_predictions = []  # Store all predicted labels
    
    # Create a DataLoader for the test dataset
    for inputs, labels in DataLoader(TensorDataset(X_test_tensor, Y_test_tensor), batch_size=512):
        inputs, labels = inputs.to(device), labels.to(device)  # Ensure inputs are on the same device
        outputs = model(inputs)  # Forward pass
        
        # Get the class with the maximum probability
        _, predicted = torch.max(outputs.data, 1)
        
        total += labels.size(0)  # Update total count
        correct += (predicted == labels).sum().item()  # Count correct predictions
        
        # Collect all true labels and predictions
        all_labels.extend(labels.cpu().numpy())  # Convert to numpy and store
        all_predictions.extend(predicted.cpu().numpy())  # Convert to numpy and store

    # Print accuracy
    print(f'Accuracy: {100 * correct / total:.2f}%')

    # Generate classification report
    print(classification_report(all_labels, all_predictions, target_names=['Class 0', 'Class 1', 'Class 2']))

    # Compute confusion matrix
    cm = confusion_matrix(all_labels, all_predictions)

    # Visualize the confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['Class 0', 'Class 1', 'Class 2'],
                yticklabels=['Class 0', 'Class 1', 'Class 2'])
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title('Confusion Matrix')
    plt.show()  # Display the plot
# Out:
# Accuracy: 81.94%
#               precision    recall  f1-score   support
#
#      Class 0       0.77      0.91      0.84      5799
#      Class 1       0.88      0.76      0.82     10635
#      Class 2       0.75      0.84      0.79      3566
#
#     accuracy                           0.82     20000
#    macro avg       0.80      0.84      0.82     20000
# weighted avg       0.83      0.82      0.82     20000

# %% [markdown]
# # PCA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# Scale the entire dataset using the previously defined scaler
X_scaled = scaler.fit_transform(X)

# Perform PCA to reduce dimensions to two components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Create a DataFrame for easy plotting
pca_df = pd.DataFrame(data=X_pca, columns=['PCA1', 'PCA2'])
pca_df['Credit Score'] = Y.values  # Add the target variable to the DataFrame

# Create a scatter plot, using a discrete color map
plt.figure(figsize=(10, 6))
scatter = plt.scatter(pca_df['PCA1'], pca_df['PCA2'], c=pca_df['Credit Score'], cmap='Set1', alpha=0.7)
plt.colorbar(scatter, label='Credit Score')  # Add a color bar for reference
plt.title('PCA of Entire Dataset Colored by Credit Score')
plt.xlabel('PCA Component 1')  # Label for the x-axis
plt.ylabel('PCA Component 2')  # Label for the y-axis
plt.grid()  # Add a grid for better readability
plt.show()  # Display the plot

# %%
# Scale the entire dataset using the previously defined scaler
X_scaled = scaler.fit_transform(X)

# Perform PCA to reduce dimensions to two components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Create a DataFrame for easy plotting
pca_df = pd.DataFrame(data=X_pca, columns=['PCA1', 'PCA2'])
pca_df['Credit Score'] = Y.values  # Add the target variable to the DataFrame

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Define colors and labels for each credit score
colors = {0: 'red', 1: 'blue', 2: 'green'}
labels = {0: 'Credit Score 0', 1: 'Credit Score 1', 2: 'Credit Score 2'}

# Plot each credit score in its own subplot
for score in colors.keys():
    subset = pca_df[pca_df['Credit Score'] == score]  # Filter data for the current credit score
    axs[score].scatter(subset['PCA1'], subset['PCA2'], color=colors[score], alpha=0.4)  # Scatter plot
    axs[score].set_title(labels[score])  # Set the title for the subplot
    axs[score].set_xlabel('PCA Component 1')  # Label for the x-axis
    axs[score].set_ylabel('PCA Component 2')  # Label for the y-axis
    axs[score].grid()  # Add a grid for better readability

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()  # Display the plot
